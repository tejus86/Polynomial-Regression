# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\HP\Desktop\Machine Learning\poly_reg.csv")

# %%
data.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
x = data.iloc[:,1].values

# %%
x = x.reshape(-1,1)

# %%
y = data.iloc[:,-1].values

# %%
y
# Out:
# array([  45000,   50000,   60000,   80000,  110000,  150000,  200000,
#         300000,  500000, 1000000], dtype=int64)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x,y,color='red')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='red')
plt.plot(x, reg.predict(x), color='blue')
plt.show()

# %% [raw]
# Blue line is Line of best fit

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree = 4)
x_poly = poly_reg.fit_transform(x)

# %% [markdown]
# x is original data,

# %%
x_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %% [raw]
# 1st column is intercept, then actual x

# %%
reg2 = LinearRegression()
reg2.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x, reg2.predict(x_poly))

# %% [raw]
# Change the degree and rerun, degree = 4 perfectly fits. check with degree = 2 and 3 to see the difference
